# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter17 ~ 20 수업은 잘 들으셨나요?
#
# Chapter01 ~ 20의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# 저번에 했던 "붕어빵 자동 판매 시스템"을 리팩토링 해봅시다 !!!
#
# 못해도 괜찮아요 ! 같이 해봅시다 !
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ### 리팩토링 과제
#
# Day4에서 만든 "붕어빵 자동 판매 시스템"은 절차적 코드로 구현되어있습니다.
# <br>
#
# Day5에서 배운 함수, 클래스 개념을 적용시켜 객체지향적으로 리팩토링을 진행해주세요

# %%
# 리팩토링 과제 힌트
# 구조는 아래와 같습니다.
class BungeoppangShop:
    def __init__(self):

    def check_stock(self):

    def process_order(self, bread_type, bread_count):

    def admin_mode(self):

    def calculate_total_sales(self):

    def main():

        if __name__ == "__main__":
            main()

# %% [markdown]
# __BungeoppangShop 클래스__
#
# - __init__(): 초기 재고, 가격, 판매량을 설정합니다.
# - check_stock(): 현재 재고를 출력합니다.
# - process_order(): 주문을 처리하고 재고를 업데이트합니다.
# - admin_mode(): 관리자 모드에서 재고를 추가합니다.
# - calculate_total_sales(): 총 매출을 계산하고 출력합니다.

# %% [markdown]
# __[과제 1: 초기화 메서드 __init__]__
#
# 목표: __init__ 메서드를 구현하여 붕어빵 가게의 초기 재고, 가격, 판매량을 설정합니다.
#
# 설명: self.stock, self.prices, self.sales 딕셔너리를 초기화하세요.
# - stock
#     - "팥붕어빵": 10
#     - "슈크림붕어빵": 8
#     - "초코붕어빵": 5
#
# - prices
#     - "팥붕어빵": 1000
#     - "슈크림붕어빵": 1200
#     - "초코붕어빵": 1500
#
# - sales
#     - "팥붕어빵": 0,
#     - "슈크림붕어빵": 0,
#     - "초코붕어빵": 0

# %%
stock = {"팥붕어빵":10, "슈크림붕어빵":10, "초코붕어빵":10}
prices = {"팥붕어빵":1000, "슈크림붕어빵":1200, "초코붕어빵":1500}
sales = {"팥붕어빵":0, "슈크림붕어빵":0, "초코붕어빵":0}

class BungeoppangShop:
    def __init__(self, stock, prices, sales):
        self.stock = stock
        self.prices = prices
        self.sales = sales

shop = BungeoppangShop(stock, prices, sales)

# %% [markdown]
# __[과제 2: 재고 확인 메서드 check_stock]__
#
# 목표: check_stock 함수를 구현하여 현재 붕어빵 재고를 출력합니다.
#
# 설명: self.stock 딕셔너리를 순회하며 각 붕어빵의 종류와 재고를 출력하세요.

# %%
    def check_stock(self):
        if self not in self.stock:
            print("다시 입력하십시오.")
        else:
            for bread in self.stock:
                print(
                    bread,
                    self.stock[bread],
                    self.prices[bread],
                    self.sales[bread],
                    sep="|")

# %% [markdown]
# __[과제 3: 주문 처리 메서드 process_order]__
#
# 목표: process_order 함수를 구현하여 손님의 주문을 처리하고 재고를 업데이트합니다.
#
# 설명: bread_type과 bread_count를 매개변수로 받아, 재고를 확인하고 충분한 경우 재고를 감소시키고 판매량을 증가시킵니다. 재고가 부족하거나 잘못된 붕어빵 종류인 경우 적절한 메시지를 출력하세요.

# %%
    def process_order(self, bread_type, bread_count):
        if bread_type not in self.stock:
            print("없는 붕어빵입니다.")
            return
        elif self.stock[bread_type] < bread_count:
            print("재고 부족합니다.")
            return
        else:
            self.stock[bread_type] -= bread_count
            self.sales[bread_type] += bread_count
        
            print(f"{bread_type} {bread_count}개 판매하였습니다.")
            print(f"남은 재고: {self.stock[bread_type]}개")

# %% [markdown]
# __[과제 4: 관리자 모드 메서드 admin_mode]__
#
# 목표: admin_mode 메서드를 구현하여 관리자 모드에서 재고를 추가할 수 있도록 합니다.
#
# 설명: bread_type과 additional_stock을 입력받아 재고를 추가합니다. 잘못된 입력 값이 들어온 경우 적절한 메시지를 출력하세요.

# %%
    def admin_mode(self, bread_type, additional_stock):
        if bread_type not in self.stock:
            print("없는 붕어빵입니다.")
            return
        else:
            self.stock[bread_type] += additional_stock
            print(f"{bread_type} 재고가 {additional_stock}개 추가되었습니다.")
            print(f"현재 재고: {self.stock[bread_type]}개")

# %% [markdown]
# __[과제 5: 매출 계산 메서드 calculate_total_sales]__
#
# 목표: calculate_total_sales 메서드를 구현하여 총 매출을 계산하고 출력합니다.
#
# 설명: self.sales와 self.prices를 사용하여 총 매출을 계산하고 출력하세요.

# %%
    def calculate_total_sales(self):
        total = 0
        for i in self.stock:
            total += self.sales[i] * self.prices[i]
        print(total)

# %% [markdown]
# __[과제 6: 메인 함수 main]__
#
# 목표: main 함수를 작성하여 프로그램의 주요 로직을 실행합니다.
#
# 설명:
# - BungeoppangShop 객체를 생성합니다.
# - 사용자에게 모드를 선택하도록 요청합니다.
# - "주문" 모드에서는 손님의 주문을 처리하고, "관리자" 모드에서는 재고를 추가할 수 있습니다.
# - 프로그램이 종료될 때 총 매출을 계산하고 데이터를 저장합니다.

# %%
    def main():
        shop = BungeoppangShop(stock, prices, sales)
        while True:
            print("==== 메뉴 ====")
            print("1. 주문하기")
            print("2. 관리자 모드")
            print("3. 재고 확인")
            print("4. 총 매출 확인")
            print("5. 종료")

            choice = input("선택: ")
            if choice == "1":
                주문 = input("주문하시겠습니까?")
                개수 = int(input("몇 개 주문하시겠습니까?"))
                shop.process_order(주문, 개수)

            elif choice == "2":
                추가 = input("추가할 빵을 선택하십시오.")
                추가개수 = int(input("몇 개 추가하시겠습니까?"))
                shop.admin_mode(추가, 추가개수)
            elif choice == "3":
                shop.check_stock()
            elif choice == "4":
                shop.calculate_total_sales()
            elif choice == "5":
                break
            else:
                print("정확한 값을 입력해주세요.")
    if __name__ == "__main__":
        main()
# Out:
# ==== 메뉴 ====
# 1. 주문하기
# 2. 관리자 모드
# 3. 재고 확인
# 4. 총 매출 확인
# 5. 종료
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 30
#      28             print("정확한 값을 입력해주세요.")
#      29 if __name__ == "__main__":
# ---> 30     main()
#
# Cell In[40], line 15, in main()
#      13     주문 = input("주문하시겠습니까?")
#      14     개수 = int(input("몇 개 주문하시겠습니까?"))
# ---> 15     shop.process_order(주문, 개수)
#      17 elif choice == "2":
#      18     추가 = input("추가할 빵을 선택하십시오.")
#
# AttributeError: 'BungeoppangShop' object has no attribute 'process_order'

# %% [markdown]
# __[과제 7: 최종 BungeoppangShop 클래스]__
#
# 함수로 리팩토링한 "붕어빵 자동 판매 시스템" 작성 후 실행합니다.

# %%
stock = {"팥붕어빵":10, "슈크림붕어빵":10, "초코붕어빵":10}
prices = {"팥붕어빵":1000, "슈크림붕어빵":1200, "초코붕어빵":1500}
sales = {"팥붕어빵":0, "슈크림붕어빵":0, "초코붕어빵":0}

class BungeoppangShop:
    def __init__(self, stock, prices, sales):
        self.stock = stock
        self.prices = prices
        self.sales = sales
    def check_stock(self):
        for bread in self.stock:
            print(
                bread,
                self.stock[bread],
                self.prices[bread],
                self.sales[bread],
                sep="|")
    def process_order(self, bread_type, bread_count):
        if bread_type not in self.stock:
            print("없는 붕어빵입니다.")
            return
        elif self.stock[bread_type] < bread_count:
            print("재고 부족합니다.")
            return
        else:
            self.stock[bread_type] -= bread_count
            self.sales[bread_type] += bread_count
        
            print(f"{bread_type} {bread_count}개 판매하였습니다.")
            print(f"남은 재고: {self.stock[bread_type]}개")
    def admin_mode(self, bread_type, additional_stock):
        if bread_type not in self.stock:
            print("없는 붕어빵입니다.")
            return
        else:
            self.stock[bread_type] += additional_stock
            print(f"{bread_type} 재고가 {additional_stock}개 추가되었습니다.")
            print(f"현재 재고: {self.stock[bread_type]}개")
    def calculate_total_sales(self):
        total = 0
        for i in self.stock:
            total += self.sales[i] * self.prices[i]
        print(total)
    def main():
        shop = BungeoppangShop(stock, prices, sales)
        while True:
            print("==== 메뉴 ====")
            print("1. 주문하기")
            print("2. 관리자 모드")
            print("3. 재고 확인")
            print("4. 총 매출 확인")
            print("5. 종료")

            choice = input("선택: ")
            if choice == "1":
                주문 = input("주문하시겠습니까?")
                개수 = int(input("몇 개 주문하시겠습니까?"))
                shop.process_order(주문, 개수)

            elif choice == "2":
                추가 = input("추가할 빵을 선택하십시오.")
                추가개수 = int(input("몇 개 추가하시겠습니까?"))
                shop.admin_mode(추가, 추가개수)
            elif choice == "3":
                shop.check_stock()
            elif choice == "4":
                shop.calculate_total_sales()
            elif choice == "5":
                break
            else:
                print("정확한 값을 입력해주세요.")
    if __name__ == "__main__":
        main()
shop = BungeoppangShop(stock, prices, sales)
# Out:
# ==== 메뉴 ====
# 1. 주문하기
# 2. 관리자 모드
# 3. 재고 확인
# 4. 총 매출 확인
# 5. 종료
# 팥붕어빵|10|1000|0
# 슈크림붕어빵|10|1200|0
# 초코붕어빵|10|1500|0
# ==== 메뉴 ====
# 1. 주문하기
# 2. 관리자 모드
# 3. 재고 확인
# 4. 총 매출 확인
# 5. 종료
